# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\craft\Desktop\IT_projects\IT_job_market_analyzer\data\processed\jobs_clean.csv")

# %%
df["Category"].value_counts().head(20)
# Out:
# Category
# UI/UX                 191
# Data Scientist        190
# Software Developer    189
# HR                    180
# Business Analyst      175
# Cloud                 170
# Name: count, dtype: int64

# %%
df["Department"].value_counts().head(20)
# Out:
# Department
# Engineering               84
# Product                   39
# Technology                30
# Sales                     26
# Information Technology    21
# Data Science              20
# Human Resources           17
# Development               14
# Design                    13
# Corporate                 12
# Software Development      12
# Operations                10
# Research                  10
# Data                      10
# IT Development            10
# Marketing                  9
# Recruiting Team            9
# Mercari                    8
# Product Development        8
# Change+                    7
# Name: count, dtype: int64

# %%
df["Location"].value_counts().head(20)
# Out:
# Location
# London, England, United Kingdom                    79
# United States                                      34
# Bengaluru, Karnataka, India                        29
# New York, New York, United States                  28
# Gurugram, Haryana, India                           24
# Athens, Attica, Greece                             21
# Riyadh, Riyadh Province, Saudi Arabia              20
# Cairo, Cairo Governorate, Egypt                    18
# Dubai, Dubai, United Arab Emirates                 18
# United Kingdom                                     15
# Paris, Île-de-France, France                       14
# Mandaluyong, Metro Manila, Philippines             14
# Lagos, Lagos, Nigeria                              13
# India                                              12
# Makati, Metro Manila, Philippines                  11
# Washington, District of Columbia, United States    11
# Boston, Massachusetts, United States               10
# ...

# %%
df["Workplace"].value_counts()
# Out:
# Workplace
# On-site     461
# Remote      413
# Hybrid      161
# Sur cite      3
# Hybride       1
# Name: count, dtype: int64

# %%
df["Type"].value_counts()
# Out:
# Type
# Full time      846
# Contract        39
# Other           14
# Temporary       13
# Part time       10
# Temps plein      4
# Name: count, dtype: int64

# %%
df["Category"].value_counts().head(10).plot(kind="pie", autopct="%1.1f%%")
plt.show()

# %%
df["Location"].value_counts().head(10).plot(kind="bar")
plt.show()

# %%
df["Workplace"].value_counts().head(10).plot(kind="pie", autopct="%1.1f%%")
plt.show()
