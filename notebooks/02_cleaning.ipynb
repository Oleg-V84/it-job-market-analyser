# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\craft\Desktop\IT_projects\IT_job_market_analyzer\data\raw\jobs.csv")

# %%
df = df.drop(columns=["Unnamed: 0"])

# %%
before = len(df)

df = df.dropna(subset=["Category"])

after = len(df)

print(f"Lines removed: {before - after}")
# Out:
# Lines removed: 0

# %%
df["Workplace"] = df["Workplace"].replace({
    "Hybride": "Hybrid",
    "Sur cite": "On-site"
})

# %%
df["Workplace"].value_counts(dropna=False)
# Out:
# Workplace
# On-site    464
# Remote     413
# Hybrid     162
# NaN         56
# Name: count, dtype: int64

# %%
df.to_csv(r"C:\Users\craft\Desktop\IT_projects\IT_job_market_analyzer\data\processed\jobs_clean.csv", index=False)
